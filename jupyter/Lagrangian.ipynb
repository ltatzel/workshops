# %%
from sympy import *
init_printing()

from IPython.display import display

# %% [markdown]
# ## Averaged Lagrangian

# %%
z = Symbol(r"z", real=True)
t = Symbol(r"t", real=True)

# %%
A = [
    Function(r"A_{1}", real=True)(z), 
    Function(r"A_{2}", real=True)(z)
]
sigma = [
    Function(r"\sigma_{1}", real=True)(z), 
    Function(r"\sigma_{2}", real=True)(z)
]
t0 = [
    Function(r"t_{1}", real=True)(z),
    Function(r"t_{2}", real=True)(z)
]
Omega = [
    Function(r"\Omega_{1}", real=True)(z),
    Function(r"\Omega_{2}", real=True)(z)
]
phi = [
    Function(r"\phi_{1}", real=True)(z),
    Function(r"\phi_{2}", real=True)(z)
]

# %%
tau = [
    Function(r"\tau_{1}", real=True)(z, t),
    Function(r"\tau_{2}", real=True)(z, t)
]
tau_expr = [
    (t - t0[0]) / sigma[0],
    (t - t0[1]) / sigma[1]
]
S = Function(r"S", real=True)

# %%
U = [
    A[0] * S(tau[0]) * exp(-I * Omega[0] * t + I * phi[0]),
    A[1] * S(tau[1]) * exp(-I * Omega[1] * t + I * phi[1])
]

display(*U)
# Out:
#                             -ⅈ⋅t⋅\Omega_{1}(z) + ⅈ⋅\phi_{1}(z)
# A_{1}(z)⋅S(\tau_{1}(z, t))⋅ℯ
#                             -ⅈ⋅t⋅\Omega_{2}(z) + ⅈ⋅\phi_{2}(z)
# A_{2}(z)⋅S(\tau_{2}(z, t))⋅ℯ

# %%
beta = [
    Symbol(r"\beta_{2}(\omega_{1})"),
    Symbol(r"\beta_{2}(\omega_{2})")
]

gamma = [
    Symbol(r"\gamma(\omega_{1})"),
    Symbol(r"\gamma(\omega_{2})")
]

def single_particle_lagrangian(u, n):
    return (
        I/2 * (u.diff(z) * u.conjugate() - u.conjugate().diff(z) * u) +
        Rational(1, 2) * beta[n] * u.diff(t) * u.conjugate().diff(t) +
        Rational(1, 2) * gamma[n] * u**2 * u.conjugate()**2)

def interaction_lagrangian(u1, u2):
    return 2 * gamma[0] * gamma[1] * u1 * u1.conjugate() * u2 * u2.conjugate()

# %%
L_sp = [
    single_particle_lagrangian(U[n], n).expand()
    for n in range(2)
]

display(*L_sp)
# Out:
#
#
#                            2     2                           2      \beta_{2}(
# \beta_{2}(\omega_{1})⋅A_{1} (z)⋅S (\tau_{1}(z, t))⋅\Omega_{1} (z)
# ───────────────────────────────────────────────────────────────── + ──────────
#                                 2
#
#                                                           2
#                  2    ⎛       ∂                          ⎞  ⎛∂
# \omega_{1})⋅A_{1} (z)⋅⎜───────────────(S(\tau_{1}(z, t)))⎟ ⋅⎜──(\tau_{1}(z, t)
#                       ⎝∂\tau_{1}(z, t)                   ⎠  ⎝∂t
# ──────────────────────────────────────────────────────────────────────────────
#                                    2
#
#   2
#  ⎞
# )⎟                            4     4
#  ⎠    \gamma(\omega_{1})⋅A_{1} (z)⋅S (\tau_{1}(z, t))          2     2
# ─── + ─────────────────────────────────────────────── + t⋅A_{1} (z)⋅S (\tau_{1
#                              2
#
#
#
#
#          d                        2     2                 d
# }(z, t))⋅──(\Omega_{1}(z)) - A_{1} (z)⋅S (\tau_{1}(z, t))⋅──(\phi_{1}(z))
#          dz                                               dz
#
#
#                            2     2                           2      \beta_{2}(
# \beta_{2}(\omega_{2})⋅A_{2} (z)⋅S (\tau_{2}(z, t))⋅\Omega_{2} (z)
# ───────────────────────────────────────────────────────────────── + ──────────
#                                 2
#
#                                                           2
#                  2    ⎛       ∂                          ⎞  ⎛∂
# \omega_{2})⋅A_{2} (z)⋅⎜───────────────(S(\tau_{2}(z, t)))⎟ ⋅⎜──(\tau_{2}(z, t)
#                       ⎝∂\tau_{2}(z, t)                   ⎠  ⎝∂t
# ──────────────────────────────────────────────────────────────────────────────
#                                    2
#
#   2
#  ⎞
# )⎟                            4     4
#  ⎠    \gamma(\omega_{2})⋅A_{2} (z)⋅S (\tau_{2}(z, t))          2     2
# ─── + ─────────────────────────────────────────────── + t⋅A_{2} (z)⋅S (\tau_{2
#                              2
#
#
#
#
#          d                        2     2                 d
# }(z, t))⋅──(\Omega_{2}(z)) - A_{2} (z)⋅S (\tau_{2}(z, t))⋅──(\phi_{2}(z))
#          dz                                               dz

# %%
def replace_tau_diff(expr, n):
    return expr.subs(tau[n].diff(t), tau_expr[n].diff(t))

L_sp = [
    replace_tau_diff(L_sp[n], n)
    for n in range(2)
]

display(*L_sp)
# Out:
#
#
#                            2     2                           2      \beta_{2}(
# \beta_{2}(\omega_{1})⋅A_{1} (z)⋅S (\tau_{1}(z, t))⋅\Omega_{1} (z)
# ───────────────────────────────────────────────────────────────── + ──────────
#                                 2
#
#
#                                                           2
#                  2    ⎛       ∂                          ⎞
# \omega_{1})⋅A_{1} (z)⋅⎜───────────────(S(\tau_{1}(z, t)))⎟
#                       ⎝∂\tau_{1}(z, t)                   ⎠    \gamma(\omega_{1
# ─────────────────────────────────────────────────────────── + ────────────────
#                              2
#                  2⋅\sigma_{1} (z)
#
#
#
#         4     4
# })⋅A_{1} (z)⋅S (\tau_{1}(z, t))          2     2                 d
# ─────────────────────────────── + t⋅A_{1} (z)⋅S (\tau_{1}(z, t))⋅──(\Omega_{1}
#        2                                                         dz
#
#
#
#
#
#             2     2                 d
# (z)) - A_{1} (z)⋅S (\tau_{1}(z, t))⋅──(\phi_{1}(z))
#                                     dz
#
#
#                            2     2                           2      \beta_{2}(
# \beta_{2}(\omega_{2})⋅A_{2} (z)⋅S (\tau_{2}(z, t))⋅\Omega_{2} (z)
# ───────────────────────────────────────────────────────────────── + ──────────
#                                 2
#
#
#                                                           2
#                  2    ⎛       ∂                          ⎞
# \omega_{2})⋅A_{2} (z)⋅⎜───────────────(S(\tau_{2}(z, t)))⎟
#                       ⎝∂\tau_{2}(z, t)                   ⎠    \gamma(\omega_{2
# ─────────────────────────────────────────────────────────── + ────────────────
#                              2
#                  2⋅\sigma_{2} (z)
#
#
#
#         4     4
# })⋅A_{2} (z)⋅S (\tau_{2}(z, t))          2     2                 d
# ─────────────────────────────── + t⋅A_{2} (z)⋅S (\tau_{2}(z, t))⋅──(\Omega_{2}
#        2                                                         dz
#
#
#
#
#
#             2     2                 d
# (z)) - A_{2} (z)⋅S (\tau_{2}(z, t))⋅──(\phi_{2}(z))
#                                     dz

# %%
L_sp_avg = [
    integrate(L_sp[n], (t, -oo, +oo)).doit().expand()
    for n in range(0, 2)
]

display(*L_sp_avg)
# Out:
#
#
#                                                ∞
#                                                ⌠
#                            2              2    ⎮   2                      \bet
# \beta_{2}(\omega_{1})⋅A_{1} (z)⋅\Omega_{1} (z)⋅⎮  S (\tau_{1}(z, t)) dt
#                                                ⌡
#                                                -∞
# ─────────────────────────────────────────────────────────────────────── + ────
#                                    2
#
#
#                             ∞
#                             ⌠
#                             ⎮                                      2
#                        2    ⎮  ⎛       ∂                          ⎞
# a_{2}(\omega_{1})⋅A_{1} (z)⋅⎮  ⎜───────────────(S(\tau_{1}(z, t)))⎟  dt
#                             ⎮  ⎝∂\tau_{1}(z, t)                   ⎠       \gam
#                             ⌡
#                             -∞
# ─────────────────────────────────────────────────────────────────────── + ────
#                                       2
#                           2⋅\sigma_{1} (z)
#
#
#
#                          ∞
#                          ⌠
#                     4    ⎮   4
# ma(\omega_{1})⋅A_{1} (z)⋅⎮  S (\tau_{1}(z, t)) dt
#                          ⌡
#                          -∞                              2    d
# ───────────────────────────────────────────────── + A_{1} (z)⋅──(\Omega_{1}(z)
#                       2                                       dz
#
#
#
#
#
#
#
#   ∞                                                      ∞
#   ⌠                                                      ⌠
#   ⎮     2                           2    d               ⎮   2
# )⋅⎮  t⋅S (\tau_{1}(z, t)) dt - A_{1} (z)⋅──(\phi_{1}(z))⋅⎮  S (\tau_{1}(z, t))
#   ⌡                                      dz              ⌡
#   -∞                                                     -∞
#
#
#
#
#
#
#
#
#
#  dt
#
#
#                                                ∞
#                                                ⌠
#                            2              2    ⎮   2                      \bet
# \beta_{2}(\omega_{2})⋅A_{2} (z)⋅\Omega_{2} (z)⋅⎮  S (\tau_{2}(z, t)) dt
#                                                ⌡
#                                                -∞
# ─────────────────────────────────────────────────────────────────────── + ────
#                                    2
#
#
#                             ∞
#                             ⌠
#                             ⎮                                      2
#                        2    ⎮  ⎛       ∂                          ⎞
# a_{2}(\omega_{2})⋅A_{2} (z)⋅⎮  ⎜───────────────(S(\tau_{2}(z, t)))⎟  dt
#                             ⎮  ⎝∂\tau_{2}(z, t)                   ⎠       \gam
#                             ⌡
#                             -∞
# ─────────────────────────────────────────────────────────────────────── + ────
#                                       2
#                           2⋅\sigma_{2} (z)
#
#
#
#                          ∞
#                          ⌠
#                     4    ⎮   4
# ma(\omega_{2})⋅A_{2} (z)⋅⎮  S (\tau_{2}(z, t)) dt
#                          ⌡
#                          -∞                              2    d
# ───────────────────────────────────────────────── + A_{2} (z)⋅──(\Omega_{2}(z)
#                       2                                       dz
#
#
#
#
#
#
#
#   ∞                                                      ∞
#   ⌠                                                      ⌠
#   ⎮     2                           2    d               ⎮   2
# )⋅⎮  t⋅S (\tau_{2}(z, t)) dt - A_{2} (z)⋅──(\phi_{2}(z))⋅⎮  S (\tau_{2}(z, t))
#   ⌡                                      dz              ⌡
#   -∞                                                     -∞
#
#
#
#
#
#
#
#
#
#  dt

# %%
I1 = Symbol("I_{1}", real=True)
I2 = Symbol("I_{2}", real=True)
I3 = Symbol("I_{3}", real=True)

def replace_integrals(expr, n):
    I1_expr = Eq(sigma[n] * I1, Integral(S(tau[n])**2, (t, -oo, +oo)))
    I2_expr = Eq(sigma[n] * I2, Integral(S(tau[n]).diff(tau[n])**2, (t, -oo, +oo)))
    I3_expr = Eq(sigma[n] * I3, Integral(S(tau[n])**4, (t, -oo, +oo)))
    return (
        expr.subs(I1_expr.rhs, I1_expr.lhs)
            .subs(
                Integral(t * S(tau[n])**2, (t, -oo, +oo)), 
                sigma[n] * t0[n] * I1)
            .subs(I2_expr.rhs, I2_expr.lhs)
            .subs(I3_expr.rhs, I3_expr.lhs))

L_sp_avg = [
    replace_integrals(L_sp_avg[n], n)
    for n in range(2)
]

display(*L_sp_avg)
# Out:
#                                  2              2
# I_{1}⋅\beta_{2}(\omega_{1})⋅A_{1} (z)⋅\Omega_{1} (z)⋅\sigma_{1}(z)
# ────────────────────────────────────────────────────────────────── + I_{1}⋅A_{
#                                 2
#
#
#   2                           d                              2
# 1} (z)⋅\sigma_{1}(z)⋅t_{1}(z)⋅──(\Omega_{1}(z)) - I_{1}⋅A_{1} (z)⋅\sigma_{1}(z
#                               dz
#
#                                                      2
#   d                 I_{2}⋅\beta_{2}(\omega_{1})⋅A_{1} (z)   I_{3}⋅\gamma(\omeg
# )⋅──(\phi_{1}(z)) + ───────────────────────────────────── + ──────────────────
#   dz                           2⋅\sigma_{1}(z)
#
#             4
# a_{1})⋅A_{1} (z)⋅\sigma_{1}(z)
# ──────────────────────────────
#      2
#                                  2              2
# I_{1}⋅\beta_{2}(\omega_{2})⋅A_{2} (z)⋅\Omega_{2} (z)⋅\sigma_{2}(z)
# ────────────────────────────────────────────────────────────────── + I_{1}⋅A_{
#                                 2
#
#
#   2                           d                              2
# 2} (z)⋅\sigma_{2}(z)⋅t_{2}(z)⋅──(\Omega_{2}(z)) - I_{1}⋅A_{2} (z)⋅\sigma_{2}(z
#                               dz
#
#                                                      2
#   d                 I_{2}⋅\beta_{2}(\omega_{2})⋅A_{2} (z)   I_{3}⋅\gamma(\omeg
# )⋅──(\phi_{2}(z)) + ───────────────────────────────────── + ──────────────────
#   dz                           2⋅\sigma_{2}(z)
#
#             4
# a_{2})⋅A_{2} (z)⋅\sigma_{2}(z)
# ──────────────────────────────
#      2

# %%
L_int = interaction_lagrangian(*U)
L_int = L_int.simplify()

display(L_int)

L_int_avg = integrate(L_int, (t, -oo, +oo))

display(L_int_avg)

I_int = Function("I_{int}")(t0[0], t0[1], sigma[0], sigma[1])
L_int_avg = L_int_avg.subs(
    Integral(S(tau[0])**2 * S(tau[1])**2, (t, -oo, +oo)), 
    I_int)

display(L_int_avg)
# Out:
#                                              2         2     2
# 2⋅\gamma(\omega_{1})⋅\gamma(\omega_{2})⋅A_{1} (z)⋅A_{2} (z)⋅S (\tau_{1}(z, t))
#
#   2
# ⋅S (\tau_{2}(z, t))
#                                                             ∞
#                                                             ⌠
#                                              2         2    ⎮   2
# 2⋅\gamma(\omega_{1})⋅\gamma(\omega_{2})⋅A_{1} (z)⋅A_{2} (z)⋅⎮  S (\tau_{1}(z,
#                                                             ⌡
#                                                             -∞
#
#
#
#      2
# t))⋅S (\tau_{2}(z, t)) dt
#                                              2         2
# 2⋅\gamma(\omega_{1})⋅\gamma(\omega_{2})⋅A_{1} (z)⋅A_{2} (z)⋅I_{int}(t_{1}(z),
#
#
# t_{2}(z), \sigma_{1}(z), \sigma_{2}(z))

# %% [markdown]
# Due to homogeneity in $t$, we can assume $I_{int}(t_{1} - t_{2}, \sigma_{1}, \sigma_{2})$

# %%
I_int_hom = Function("I_{int}")(t0[0] - t0[1], sigma[0], sigma[1])
L_int_avg = L_int_avg.subs(I_int, I_int_hom)

display(L_int_avg)
# Out:
#                                              2         2
# 2⋅\gamma(\omega_{1})⋅\gamma(\omega_{2})⋅A_{1} (z)⋅A_{2} (z)⋅I_{int}(t_{1}(z) -
#
#
#  t_{2}(z), \sigma_{1}(z), \sigma_{2}(z))

# %%
L_avg = L_sp_avg[0] + L_sp_avg[1] + L_int_avg

display(L_avg)
# Out:
#                                  2              2
# I_{1}⋅\beta_{2}(\omega_{1})⋅A_{1} (z)⋅\Omega_{1} (z)⋅\sigma_{1}(z)   I_{1}⋅\be
# ────────────────────────────────────────────────────────────────── + ─────────
#                                 2
#
#                         2              2
# ta_{2}(\omega_{2})⋅A_{2} (z)⋅\Omega_{2} (z)⋅\sigma_{2}(z)              2
# ───────────────────────────────────────────────────────── + I_{1}⋅A_{1} (z)⋅\s
#                        2
#
#
#                      d                              2                  d
# igma_{1}(z)⋅t_{1}(z)⋅──(\Omega_{1}(z)) - I_{1}⋅A_{1} (z)⋅\sigma_{1}(z)⋅──(\phi
#                      dz                                                dz
#
#
#                       2                           d
# _{1}(z)) + I_{1}⋅A_{2} (z)⋅\sigma_{2}(z)⋅t_{2}(z)⋅──(\Omega_{2}(z)) - I_{1}⋅A_
#                                                   dz
#
#                                                                          2
#    2                  d                 I_{2}⋅\beta_{2}(\omega_{1})⋅A_{1} (z)
# {2} (z)⋅\sigma_{2}(z)⋅──(\phi_{2}(z)) + ─────────────────────────────────────
#                       dz                           2⋅\sigma_{1}(z)
#
#                                    2                                    4
#   I_{2}⋅\beta_{2}(\omega_{2})⋅A_{2} (z)   I_{3}⋅\gamma(\omega_{1})⋅A_{1} (z)⋅\
# + ───────────────────────────────────── + ────────────────────────────────────
#              2⋅\sigma_{2}(z)                                     2
#
#                                              4
# sigma_{1}(z)   I_{3}⋅\gamma(\omega_{2})⋅A_{2} (z)⋅\sigma_{2}(z)
# ──────────── + ──────────────────────────────────────────────── + 2⋅\gamma(\om
#                                       2
#
#
#                                  2         2
# ega_{1})⋅\gamma(\omega_{2})⋅A_{1} (z)⋅A_{2} (z)⋅I_{int}(t_{1}(z) - t_{2}(z), \
#
#
#
#
# sigma_{1}(z), \sigma_{2}(z))

# %% [markdown]
# ## Equations of motion

# %%
def variation(expr, q):
    p = Symbol("p")
    return expr.diff(q) - expr.subs(q.diff(z), p).diff(p).diff(z)

# %%
for n in range(2):
    eq = (variation(L_avg, phi[n]) / I1).expand()
    display(eq)
    
N = [Symbol("N_{1}"), Symbol("N_{2}")]

N_expr = [
    Eq(N[n], sigma[n] * A[n]**2)
    for n in range(2)
]
display(*N_expr)

A_expr = [
    Eq(A[n]**2, N[n] / sigma[n])
    for n in range(2)
]
display(*A_expr)
# Out:
#      2    d                                            d
# A_{1} (z)⋅──(\sigma_{1}(z)) + 2⋅A_{1}(z)⋅\sigma_{1}(z)⋅──(A_{1}(z))
#           dz                                           dz
#      2    d                                            d
# A_{2} (z)⋅──(\sigma_{2}(z)) + 2⋅A_{2}(z)⋅\sigma_{2}(z)⋅──(A_{2}(z))
#           dz                                           dz
#              2
# N_{1} = A_{1} (z)⋅\sigma_{1}(z)
#              2
# N_{2} = A_{2} (z)⋅\sigma_{2}(z)
#      2          N_{1}
# A_{1} (z) = ─────────────
#             \sigma_{1}(z)
#      2          N_{2}
# A_{2} (z) = ─────────────
#             \sigma_{2}(z)

# %%
for n in range(2):
    L_avg = L_avg.subs(A_expr[n].lhs, A_expr[n].rhs)
    
display(L_avg)
# Out:
#                                             2
# I_{1}⋅N_{1}⋅\beta_{2}(\omega_{1})⋅\Omega_{1} (z)                        d
# ──────────────────────────────────────────────── + I_{1}⋅N_{1}⋅t_{1}(z)⋅──(\Om
#                        2                                                dz
#
#
#
#                           d                 I_{1}⋅N_{2}⋅\beta_{2}(\omega_{2})⋅
# ega_{1}(z)) - I_{1}⋅N_{1}⋅──(\phi_{1}(z)) + ──────────────────────────────────
#                           dz                                       2
#
#
#           2
# \Omega_{2} (z)                        d                               d
# ────────────── + I_{1}⋅N_{2}⋅t_{2}(z)⋅──(\Omega_{2}(z)) - I_{1}⋅N_{2}⋅──(\phi_
#                                       dz                              dz
#
#
#
#           I_{2}⋅N_{1}⋅\beta_{2}(\omega_{1})   I_{2}⋅N_{2}⋅\beta_{2}(\omega_{2}
# {2}(z)) + ───────────────────────────────── + ────────────────────────────────
#                                2                                   2
#                    2⋅\sigma_{1} (z)                    2⋅\sigma_{2} (z)
#
#                2                                 2
# )   I_{3}⋅N_{1} ⋅\gamma(\omega_{1})   I_{3}⋅N_{2} ⋅\gamma(\omega_{2})   2⋅N_{1
# ─ + ─────────────────────────────── + ─────────────────────────────── + ──────
#             2⋅\sigma_{1}(z)                   2⋅\sigma_{2}(z)
#
#
#
# }⋅N_{2}⋅\gamma(\omega_{1})⋅\gamma(\omega_{2})⋅I_{int}(t_{1}(z) - t_{2}(z), \si
# ──────────────────────────────────────────────────────────────────────────────
#                                    \sigma_{1}(z)⋅\sigma_{2}(z)
#
#
#
# gma_{1}(z), \sigma_{2}(z))
# ──────────────────────────

# %%
Eq_Omega = []

for n in range(2):
    eq = variation(L_avg, Omega[n])
    eq = eq / I1 / N[n]
    eq = eq.expand()
    
    lhs = t0[n].diff(z)
    rhs = solve(eq, lhs)[0]
    eq = Eq(lhs, rhs)
    
    Eq_Omega.append(eq)
    
display(*Eq_Omega)
# Out:
# d
# ──(t_{1}(z)) = \beta_{2}(\omega_{1})⋅\Omega_{1}(z)
# dz
# d
# ──(t_{2}(z)) = \beta_{2}(\omega_{2})⋅\Omega_{2}(z)
# dz

# %%
Eq_t0 = []

for n in range(2):
    eq = variation(L_avg, t0[n])
    eq = eq / I1 / N[n]
    eq = eq.expand()
    
    lhs = Omega[n].diff(z)
    rhs = solve(eq, lhs)[0]
    eq = Eq(lhs, rhs)
    
    Eq_t0.append(eq)
    
display(*Eq_t0)
# Out:
#                                                                    ⎛ ∂
#                     -2⋅N_{2}⋅\gamma(\omega_{1})⋅\gamma(\omega_{2})⋅⎜───(I_{int
# d                                                                  ⎝∂ξ₁
# ──(\Omega_{1}(z)) = ──────────────────────────────────────────────────────────
# dz                                                             I_{1}⋅\sigma_{1
#
#                                     ⎞│
# }(ξ₁, \sigma_{1}(z), \sigma_{2}(z)))⎟│
#                                     ⎠│ξ₁=t_{1}(z) - t_{2}(z)
# ─────────────────────────────────────────────────────────────
# }(z)⋅\sigma_{2}(z)
#                                                                   ⎛ ∂
#                     2⋅N_{1}⋅\gamma(\omega_{1})⋅\gamma(\omega_{2})⋅⎜───(I_{int}
# d                                                                 ⎝∂ξ₁
# ──(\Omega_{2}(z)) = ──────────────────────────────────────────────────────────
# dz                                                            I_{1}⋅\sigma_{1}
#
#                                    ⎞│
# (ξ₁, \sigma_{1}(z), \sigma_{2}(z)))⎟│
#                                    ⎠│ξ₁=t_{1}(z) - t_{2}(z)
# ───────────────────────────────────────────────────────────
# (z)⋅\sigma_{2}(z)

# %%
Eq_momentum_conservation = Eq(
    N[0] * Eq_t0[0].lhs + N[1] * Eq_t0[1].lhs,
    N[0] * Eq_t0[0].rhs + N[1] * Eq_t0[1].rhs)

display(Eq_momentum_conservation)
# Out:
#       d                         d
# N_{1}⋅──(\Omega_{1}(z)) + N_{2}⋅──(\Omega_{2}(z)) = 0
#       dz                        dz

# %%
Eq_sigma = []

for n in range(2):
    eq = variation(L_avg, sigma[n])
    eq = eq * sigma[n]**2 * sigma[1 - n]
    eq = eq.expand()
    Eq_sigma.append(Eq(eq, 0))
    
display(*Eq_sigma)
# Out:
#                                                                2
#   I_{2}⋅N_{1}⋅\beta_{2}(\omega_{1})⋅\sigma_{2}(z)   I_{3}⋅N_{1} ⋅\gamma(\omega
# - ─────────────────────────────────────────────── - ──────────────────────────
#                    \sigma_{1}(z)                                          2
#
#
# _{1})⋅\sigma_{2}(z)
# ─────────────────── - 2⋅N_{1}⋅N_{2}⋅\gamma(\omega_{1})⋅\gamma(\omega_{2})⋅I_{i
#
#
#
#
# nt}(t_{1}(z) - t_{2}(z), \sigma_{1}(z), \sigma_{2}(z)) + 2⋅N_{1}⋅N_{2}⋅\gamma(
#
#
#
#                                                    d
# \omega_{1})⋅\gamma(\omega_{2})⋅\sigma_{1}(z)⋅──────────────(I_{int}(t_{1}(z) -
#                                              d\sigma_{1}(z)
#
#
#
#  t_{2}(z), \sigma_{1}(z), \sigma_{2}(z))) = 0
#                                                                2
#   I_{2}⋅N_{2}⋅\beta_{2}(\omega_{2})⋅\sigma_{1}(z)   I_{3}⋅N_{2} ⋅\gamma(\omega
# - ─────────────────────────────────────────────── - ──────────────────────────
#                    \sigma_{2}(z)                                          2
#
#
# _{2})⋅\sigma_{1}(z)
# ─────────────────── - 2⋅N_{1}⋅N_{2}⋅\gamma(\omega_{1})⋅\gamma(\omega_{2})⋅I_{i
#
#
#
#
# nt}(t_{1}(z) - t_{2}(z), \sigma_{1}(z), \sigma_{2}(z)) + 2⋅N_{1}⋅N_{2}⋅\gamma(
#
#
#
#                                                    d
# \omega_{1})⋅\gamma(\omega_{2})⋅\sigma_{2}(z)⋅──────────────(I_{int}(t_{1}(z) -
#                                              d\sigma_{2}(z)
#
#
#
#  t_{2}(z), \sigma_{1}(z), \sigma_{2}(z))) = 0

# %% [markdown]
# ## Center of mass coordinates

# %%
dt = Function(r"\Delta t")(z)
dt_expr = Eq(dt, t0[0] - t0[1])

tc = Function(r"t_{0}")(z)
tc_expr = Eq(tc, Rational(1, 2) * (t0[0] + t0[1]))

display(dt_expr, tc_expr)
# Out:
# \Delta t(z) = t_{1}(z) - t_{2}(z)
#            t_{1}(z)   t_{2}(z)
# t_{0}(z) = ──────── + ────────
#               2          2

# %%
I_int_hom = I_int_hom.subs(t0[0] - t0[1], dt)
display(I_int_hom)
# Out:
# I_{int}(\Delta t(z), \sigma_{1}(z), \sigma_{2}(z))

# %%
Eq_dt = Eq(dt.diff(), Eq_Omega[0].rhs - Eq_Omega[1].rhs)
display(Eq_dt)

Eq_tc = Eq(tc.diff(), Rational(1, 2) * (Eq_Omega[0].rhs + Eq_Omega[1].rhs))
display(Eq_tc)
# Out:
# d
# ──(\Delta t(z)) = \beta_{2}(\omega_{1})⋅\Omega_{1}(z) - \beta_{2}(\omega_{2})⋅
# dz
#
#
# \Omega_{2}(z)
# d              \beta_{2}(\omega_{1})⋅\Omega_{1}(z)   \beta_{2}(\omega_{2})⋅\Om
# ──(t_{0}(z)) = ─────────────────────────────────── + ─────────────────────────
# dz                              2                                     2
#
# ega_{2}(z)
# ──────────

# %%
Eq_t0 = [
    Eq_t0[n].subs(t0[0] - t0[1], dt)
    for n in range(2)
]
display(*Eq_t0)
# Out:
#                                                                    ⎛ ∂
#                     -2⋅N_{2}⋅\gamma(\omega_{1})⋅\gamma(\omega_{2})⋅⎜───(I_{int
# d                                                                  ⎝∂ξ₁
# ──(\Omega_{1}(z)) = ──────────────────────────────────────────────────────────
# dz                                                         I_{1}⋅\sigma_{1}(z)
#
#                                     ⎞│
# }(ξ₁, \sigma_{1}(z), \sigma_{2}(z)))⎟│
#                                     ⎠│ξ₁=\Delta t(z)
# ─────────────────────────────────────────────────────
# ⋅\sigma_{2}(z)
#                                                                   ⎛ ∂
#                     2⋅N_{1}⋅\gamma(\omega_{1})⋅\gamma(\omega_{2})⋅⎜───(I_{int}
# d                                                                 ⎝∂ξ₁
# ──(\Omega_{2}(z)) = ──────────────────────────────────────────────────────────
# dz                                                        I_{1}⋅\sigma_{1}(z)⋅
#
#                                    ⎞│
# (ξ₁, \sigma_{1}(z), \sigma_{2}(z)))⎟│
#                                    ⎠│ξ₁=\Delta t(z)
# ───────────────────────────────────────────────────
# \sigma_{2}(z)

# %%
Eq_sigma = [
    Eq_sigma[n].subs(t0[0] - t0[1], dt)
    for n in range(2)
]
display(*Eq_sigma)
# Out:
#                                                                2
#   I_{2}⋅N_{1}⋅\beta_{2}(\omega_{1})⋅\sigma_{2}(z)   I_{3}⋅N_{1} ⋅\gamma(\omega
# - ─────────────────────────────────────────────── - ──────────────────────────
#                    \sigma_{1}(z)                                          2
#
#
# _{1})⋅\sigma_{2}(z)
# ─────────────────── - 2⋅N_{1}⋅N_{2}⋅\gamma(\omega_{1})⋅\gamma(\omega_{2})⋅I_{i
#
#
#
#
# nt}(\Delta t(z), \sigma_{1}(z), \sigma_{2}(z)) + 2⋅N_{1}⋅N_{2}⋅\gamma(\omega_{
#
#
#
#                                            d
# 1})⋅\gamma(\omega_{2})⋅\sigma_{1}(z)⋅──────────────(I_{int}(\Delta t(z), \sigm
#                                      d\sigma_{1}(z)
#
#
#
# a_{1}(z), \sigma_{2}(z))) = 0
#                                                                2
#   I_{2}⋅N_{2}⋅\beta_{2}(\omega_{2})⋅\sigma_{1}(z)   I_{3}⋅N_{2} ⋅\gamma(\omega
# - ─────────────────────────────────────────────── - ──────────────────────────
#                    \sigma_{2}(z)                                          2
#
#
# _{2})⋅\sigma_{1}(z)
# ─────────────────── - 2⋅N_{1}⋅N_{2}⋅\gamma(\omega_{1})⋅\gamma(\omega_{2})⋅I_{i
#
#
#
#
# nt}(\Delta t(z), \sigma_{1}(z), \sigma_{2}(z)) + 2⋅N_{1}⋅N_{2}⋅\gamma(\omega_{
#
#
#
#                                            d
# 1})⋅\gamma(\omega_{2})⋅\sigma_{2}(z)⋅──────────────(I_{int}(\Delta t(z), \sigm
#                                      d\sigma_{2}(z)
#
#
#
# a_{1}(z), \sigma_{2}(z))) = 0

# %% [markdown]
# Essentially, we have an isolated system of equations

# %%
display(Eq_dt)
display(*Eq_t0)
display(*Eq_sigma)
# Out:
# d
# ──(\Delta t(z)) = \beta_{2}(\omega_{1})⋅\Omega_{1}(z) - \beta_{2}(\omega_{2})⋅
# dz
#
#
# \Omega_{2}(z)
#                                                                    ⎛ ∂
#                     -2⋅N_{2}⋅\gamma(\omega_{1})⋅\gamma(\omega_{2})⋅⎜───(I_{int
# d                                                                  ⎝∂ξ₁
# ──(\Omega_{1}(z)) = ──────────────────────────────────────────────────────────
# dz                                                         I_{1}⋅\sigma_{1}(z)
#
#                                     ⎞│
# }(ξ₁, \sigma_{1}(z), \sigma_{2}(z)))⎟│
#                                     ⎠│ξ₁=\Delta t(z)
# ─────────────────────────────────────────────────────
# ⋅\sigma_{2}(z)
#                                                                   ⎛ ∂
#                     2⋅N_{1}⋅\gamma(\omega_{1})⋅\gamma(\omega_{2})⋅⎜───(I_{int}
# d                                                                 ⎝∂ξ₁
# ──(\Omega_{2}(z)) = ──────────────────────────────────────────────────────────
# dz                                                        I_{1}⋅\sigma_{1}(z)⋅
#
#                                    ⎞│
# (ξ₁, \sigma_{1}(z), \sigma_{2}(z)))⎟│
#                                    ⎠│ξ₁=\Delta t(z)
# ───────────────────────────────────────────────────
# \sigma_{2}(z)
#                                                                2
#   I_{2}⋅N_{1}⋅\beta_{2}(\omega_{1})⋅\sigma_{2}(z)   I_{3}⋅N_{1} ⋅\gamma(\omega
# - ─────────────────────────────────────────────── - ──────────────────────────
#                    \sigma_{1}(z)                                          2
#
#
# _{1})⋅\sigma_{2}(z)
# ─────────────────── - 2⋅N_{1}⋅N_{2}⋅\gamma(\omega_{1})⋅\gamma(\omega_{2})⋅I_{i
#
#
#
#
# nt}(\Delta t(z), \sigma_{1}(z), \sigma_{2}(z)) + 2⋅N_{1}⋅N_{2}⋅\gamma(\omega_{
#
#
#
#                                            d
# 1})⋅\gamma(\omega_{2})⋅\sigma_{1}(z)⋅──────────────(I_{int}(\Delta t(z), \sigm
#                                      d\sigma_{1}(z)
#
#
#
# a_{1}(z), \sigma_{2}(z))) = 0
#                                                                2
#   I_{2}⋅N_{2}⋅\beta_{2}(\omega_{2})⋅\sigma_{1}(z)   I_{3}⋅N_{2} ⋅\gamma(\omega
# - ─────────────────────────────────────────────── - ──────────────────────────
#                    \sigma_{2}(z)                                          2
#
#
# _{2})⋅\sigma_{1}(z)
# ─────────────────── - 2⋅N_{1}⋅N_{2}⋅\gamma(\omega_{1})⋅\gamma(\omega_{2})⋅I_{i
#
#
#
#
# nt}(\Delta t(z), \sigma_{1}(z), \sigma_{2}(z)) + 2⋅N_{1}⋅N_{2}⋅\gamma(\omega_{
#
#
#
#                                            d
# 1})⋅\gamma(\omega_{2})⋅\sigma_{2}(z)⋅──────────────(I_{int}(\Delta t(z), \sigm
#                                      d\sigma_{2}(z)
#
#
#
# a_{1}(z), \sigma_{2}(z))) = 0

# %% [markdown]
# The last pair is essentially just a system of equations for $\sigma_{1}$ and $\sigma_{2}$ as functions of $\Delta t$.

# %% [markdown]
# ## Gaussian pulses

# %%
inner = exp(-(tau[0])**2)**2 * exp(-tau[1]**2)**2

for n in range(2):
    inner = inner.subs(tau[n], tau_expr[n])
    
inner = inner.simplify()
display(inner)
# Out:
#                    2                   2
#    2⋅(t - t_{1}(z))    2⋅(t - t_{2}(z))
#  - ───────────────── - ─────────────────
#                2                   2
#      \sigma_{1} (z)      \sigma_{2} (z)
# ℯ

# %%
power = - inner.args[0]
power = power.expand()
a_sq = power.coeff(t**2)
ab = power.coeff(t) / 2
c = (power - a_sq * t**2 - 2 * ab * t).simplify()

display(power)
display(a_sq, ab, c)
# Out:
#         2                2                                                  2
#      2⋅t              2⋅t          4⋅t⋅t_{2}(z)     4⋅t⋅t_{1}(z)     2⋅t_{2} (
# ────────────── + ────────────── - ────────────── - ────────────── + ──────────
#           2                2                2                2
# \sigma_{2} (z)   \sigma_{1} (z)   \sigma_{2} (z)   \sigma_{1} (z)   \sigma_{2}
#
#                2
# z)      2⋅t_{1} (z)
# ──── + ──────────────
# 2                2
#  (z)   \sigma_{1} (z)
#       2                2
# ────────────── + ──────────────
#           2                2
# \sigma_{2} (z)   \sigma_{1} (z)
#     2⋅t_{2}(z)       2⋅t_{1}(z)
# - ────────────── - ──────────────
#             2                2
#   \sigma_{2} (z)   \sigma_{1} (z)
#         2                2
#  2⋅t_{2} (z)      2⋅t_{1} (z)
# ────────────── + ──────────────
#           2                2
# \sigma_{2} (z)   \sigma_{1} (z)

# %%
a = sqrt(a_sq)
b = ab / a

fsq_power = a**2 * (t + b/a)**2 - b**2 + c
assert (fsq_power - power).simplify() == 0

# %%
residue = - 2 * (t0[0] - t0[1])**2 / (sigma[0]**2 + sigma[1]**2)
assert (b**2 - c - residue).simplify() == 0

fsq_inner = exp(- a**2 * t**2) * exp(residue)
display(Eq(I_int_hom, Integral(fsq_inner, (t, -oo, +oo))))
# Out:
#                                                              ∞
#                                                              ⌠
#                                                              ⎮
#                                                              ⎮    2 ⎛        2
#                                                              ⎮   t ⋅⎜- ───────
#                                                              ⎮      ⎜
#                                                              ⎮      ⎝  \sigma_
# I_{int}(t_{1}(z) - t_{2}(z), \sigma_{1}(z), \sigma_{2}(z)) = ⎮  ℯ
#                                                              ⌡
#                                                              -∞
#
#
#
#                                                       2
#                 2       ⎞     -2⋅(t_{1}(z) - t_{2}(z))
# ─────── - ──────────────⎟  ───────────────────────────────
#    2                2   ⎟            2                2
# {2} (z)   \sigma_{1} (z)⎠  \sigma_{1} (z) + \sigma_{2} (z)
#                          ⋅ℯ                                dt

# %%
I_int_expr = Eq(I_int_hom, sqrt(pi) / a * exp(residue))
display(I_int_expr)
# Out:
#
#                                                                      -2⋅(t_{1}
#                                                                   ────────────
#                                                                             2
#                                                                   \sigma_{1} (
#                                                               √π⋅ℯ
# I_{int}(t_{1}(z) - t_{2}(z), \sigma_{1}(z), \sigma_{2}(z)) = ─────────────────
#                                                                   ____________
#                                                                  ╱       2
#                                                                 ╱  ───────────
#                                                                ╱             2
#                                                              ╲╱    \sigma_{2}
#
#                2
# (z) - t_{2}(z))
# ───────────────────
#                2
# z) + \sigma_{2} (z)
#
# ─────────────────────
# _____________________
#             2
# ─── + ──────────────
#                 2
# (z)   \sigma_{1} (z)

# %%
I_int_expr = I_int_expr.subs(t0[0] - t0[1], dt)
display(I_int_expr)
# Out:
#                                                                              2
#                                                                   -2⋅\Delta t
#                                                           ────────────────────
#                                                                     2
#                                                           \sigma_{1} (z) + \si
#                                                       √π⋅ℯ
# I_{int}(\Delta t(z), \sigma_{1}(z), \sigma_{2}(z)) = ─────────────────────────
#                                                           ____________________
#                                                          ╱       2
#                                                         ╱  ────────────── + ──
#                                                        ╱             2
#                                                      ╲╱    \sigma_{2} (z)   \s
#
#
# (z)
# ───────────
#        2
# gma_{2} (z)
#
# ─────────────
# _____________
#     2
# ────────────
#         2
# igma_{1} (z)

# %% [markdown]
# ## Small oscillations

# %%
lhs = Eq_dt.lhs.diff(z)
rhs = Eq_dt.rhs.diff(z).subs(Eq_t0[0].lhs, Eq_t0[0].rhs).subs(Eq_t0[1].lhs, Eq_t0[1].rhs)


Eq_osc = Eq(lhs, rhs.simplify())
display(Eq_osc)
# Out:
#
#   2                -2⋅\gamma(\omega_{1})⋅\gamma(\omega_{2})⋅(N_{1}⋅\beta_{2}(\
#  d
# ───(\Delta t(z)) = ───────────────────────────────────────────────────────────
#   2
# dz
#
#                                                d
# omega_{2}) + N_{2}⋅\beta_{2}(\omega_{1}))⋅────────────(I_{int}(\Delta t(z), \s
#                                           d\Delta t(z)
# ──────────────────────────────────────────────────────────────────────────────
#        I_{1}⋅\sigma_{1}(z)⋅\sigma_{2}(z)
#
#
#
# igma_{1}(z), \sigma_{2}(z)))
#
# ─────────────────────────────

# %%
sigma_dt = [
    Function(r"\sigma_{1}")(dt),
    Function(r"\sigma_{2}")(dt)
]

rhs = Eq_osc.rhs
for n in range(2):
    rhs = rhs.replace(sigma[n], sigma_dt[n])

Eq_osc = Eq(Eq_osc.lhs, rhs)
display(Eq_osc)
# Out:
#
#   2                -2⋅\gamma(\omega_{1})⋅\gamma(\omega_{2})⋅(N_{1}⋅\beta_{2}(\
#  d
# ───(\Delta t(z)) = ───────────────────────────────────────────────────────────
#   2
# dz
#
#                                           ⎛     d
# omega_{2}) + N_{2}⋅\beta_{2}(\omega_{1}))⋅⎜────────────(I_{int}(\Delta t(z), \
#                                           ⎝d\Delta t(z)
# ──────────────────────────────────────────────────────────────────────────────
#                                      I_{1}⋅\sigma_{1}(\Delta t(z))⋅\sigma_{2}(
#
#
#                              ⎞│
# sigma_{1}(z), \sigma_{2}(z)))⎟│
#                              ⎠│\sigma_{2}(z)=\sigma_{2}(\Delta t(z)), \sigma_{
# ──────────────────────────────────────────────────────────────────────────────
# \Delta t(z))
#
#
#
#
# 1}(z)=\sigma_{1}(\Delta t(z))
# ──────────────────────────────

# %%
Eq_osc.rhs.subs(I_int_hom, I_int_expr.rhs).diff(dt).doit().subs(dt, 0)
# Out:
# 4⋅√2⋅√π⋅\gamma(\omega_{1})⋅\gamma(\omega_{2})⋅(N_{1}⋅\beta_{2}(\omega_{2}) + N
# ──────────────────────────────────────────────────────────────────────────────
#                                              _________________________________
#       ⎛          2                2   ⎞     ╱       1                1
# I_{1}⋅⎝\sigma_{1} (0) + \sigma_{2} (0)⎠⋅   ╱  ────────────── + ──────────────
#                                           ╱             2                2
#                                         ╲╱    \sigma_{2} (0)   \sigma_{1} (0)
#
# _{2}⋅\beta_{2}(\omega_{1}))
# ────────────────────────────
#
#
# ⋅\sigma_{1}(0)⋅\sigma_{2}(0)

# %%
I_int_expr.rhs.diff(dt, 2).subs(dt, 0)
# Out:
#                                -2⋅√2⋅√π
# ────────────────────────────────────────────────────────────────────────
#                                        _________________________________
# ⎛          2                2   ⎞     ╱       1                1
# ⎝\sigma_{1} (z) + \sigma_{2} (z)⎠⋅   ╱  ────────────── + ──────────────
#                                     ╱             2                2
#                                   ╲╱    \sigma_{2} (z)   \sigma_{1} (z)

# %%
Eq_a = Eq_sigma[0].subs(I_int_hom, I_int_expr.rhs).doit().subs(dt, 0)
Eq_b = Eq_sigma[1].subs(I_int_hom, I_int_expr.rhs).doit().subs(dt, 0)

display(Eq_a, Eq_b)
# Out:
#                                                                2
#   I_{2}⋅N_{1}⋅\beta_{2}(\omega_{1})⋅\sigma_{2}(z)   I_{3}⋅N_{1} ⋅\gamma(\omega
# - ─────────────────────────────────────────────── - ──────────────────────────
#                    \sigma_{1}(z)                                          2
#
#
#
#
#
#
# _{1})⋅\sigma_{2}(z)   2⋅√π⋅N_{1}⋅N_{2}⋅\gamma(\omega_{1})⋅\gamma(\omega_{2})
# ─────────────────── - ────────────────────────────────────────────────────── +
#                                    _________________________________
#                                   ╱       2                2
#                                  ╱  ────────────── + ──────────────
#                                 ╱             2                2
#                               ╲╱    \sigma_{2} (z)   \sigma_{1} (z)
#
#
#  4⋅√π⋅N_{1}⋅N_{2}⋅\gamma(\omega_{1})⋅\gamma(\omega_{2})
#  ────────────────────────────────────────────────────── = 0
#                                    3/2
#   ⎛      2                2       ⎞              2
#   ⎜────────────── + ──────────────⎟   ⋅\sigma_{1} (z)
#   ⎜          2                2   ⎟
#   ⎝\sigma_{2} (z)   \sigma_{1} (z)⎠
#                                                                2
#   I_{2}⋅N_{2}⋅\beta_{2}(\omega_{2})⋅\sigma_{1}(z)   I_{3}⋅N_{2} ⋅\gamma(\omega
# - ─────────────────────────────────────────────── - ──────────────────────────
#                    \sigma_{2}(z)                                          2
#
#
#
#
#
#
# _{2})⋅\sigma_{1}(z)   2⋅√π⋅N_{1}⋅N_{2}⋅\gamma(\omega_{1})⋅\gamma(\omega_{2})
# ─────────────────── - ────────────────────────────────────────────────────── +
#                                    _________________________________
#                                   ╱       2                2
#                                  ╱  ────────────── + ──────────────
#                                 ╱             2                2
#                               ╲╱    \sigma_{2} (z)   \sigma_{1} (z)
#
#
#  4⋅√π⋅N_{1}⋅N_{2}⋅\gamma(\omega_{1})⋅\gamma(\omega_{2})
#  ────────────────────────────────────────────────────── = 0
#                                    3/2
#   ⎛      2                2       ⎞              2
#   ⎜────────────── + ──────────────⎟   ⋅\sigma_{2} (z)
#   ⎜          2                2   ⎟
#   ⎝\sigma_{2} (z)   \sigma_{1} (z)⎠
